# %%
import math


def arrangement(n, k):
    A = math.factorial(n)/math.factorial(n - k)
    return A

# %%
def combination(n, k):
    C = math.factorial(n) / (math.factorial(k) * math.factorial(n - k))
    return C

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def bernouli_formula(p, n, k):
    q = 1 - p
    P = combination(n, k) * pow(p, k)*pow(q, n-k)
    return P

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = 1/2
q = 1 - p
k = 4
n = 6

P = bernouli_formula(p, n, k)
P
# Out:
# 0.234375

# %%
prob_boys = 0.515
prob_girls = 0.485

p = prob_girls

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = 2
n = 6

P = 0

for k in range(m + 1):
    P += bernouli_formula(p, n, k)
    print(P)

print("answer is:", P)
# Out:
# 0.018657067133265627
# 0.1240785532649219
# 0.3722796249826563
# answer is: 0.3722796249826563

# %%
n = pow(0.515, 6)
n
# Out:
# 0.018657067133265627

# %%
def bernouli_formula_with_constrains(p, n, m):
    P = 0

    for k in range(m + 1):
        P += bernouli_formula(p, n, k)

    return P

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def poisson(n, p, k):
    jl = p*n
    P = pow(jl, k) / math.factorial(k)
    return P

# %%
n  = 10000
p = 0.0001
k = 5

P = poisson(n, p, k)
P
# Out:
# 0.008333333333333333

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = 80/100

n = 250

q = 1 - p

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def most_likely_number(p,n):  # Todo
    q = 1- p

# %% [markdown]
# ## Теорема Муавра-Лапласа

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# n = 100
# k1 = 6
# k2 = 18

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def integral_moivre_laplace(n, p, k,theta1,theta2):
 q= 1-p

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = 0.25
n = 300
k = 75

# %%
def local_moivre_laplace(n, p, k):
  q = 1- p
  phi = lambda x: (1/math.sqrt(2*math.pi)) * math.exp(-math.pow(x, 2)/2)
  x = (k - n*p) / math.sqrt(n*p*q)
  P = 1/math.sqrt(n* p* q) * phi(x)
  return P

# %%
P = local_moivre_laplace(n, p, k)
P
# Out:
# 0.05319230405352436

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p_non_std = 1 - 0.95
n = 10
m = 1

# %%
P = bernouli_formula_with_constrains(p_non_std, n, m)
P
# Out:
# 0.9138616441006835

# %%
P = math.pow(0.95,10) + 0.5* math.pow(0.95,9)
P
# Out:
# 0.9138616441006833

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = 30/100
n = 6
k = 4

# %%
P = bernouli_formula(p, n, k)
P
# Out:
# 0.05953499999999999

# %%
P = local_moivre_laplace(n, p, k)
P
# Out:
# 0.052071926494735715

# %% [markdown]
# Похибка є

# %% [markdown]
# якщо n*p*q > 9 то локальна теорема Муавра-Лапласа буде працювати точніше, в іншому випадку цю теорему застосовувати небажано

# %%
import math


def arrangement(n, k):
    A = math.factorial(n)/math.factorial(n - k)
    return A

# %%
def combination(n, k):
    C = math.factorial(n) / (math.factorial(k) * math.factorial(n - k))
    return C

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
balls_count = 20
balls_white_count = 10
balls_white_count = 10

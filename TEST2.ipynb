# %% [markdown]
# > TC41 Bogdan Zayats

# %%
import math


def arrangement(n, k):
    A = math.factorial(n)/math.factorial(n - k)
    return A

# %%
def combination(n, k):
    C = math.factorial(n) / (math.factorial(k) * math.factorial(n - k))
    return C

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars = 15 # arbitary number, result does'nt change
trucks  = 3*cars

diesel_trucks = 0.5 *trucks
print(diesel_trucks)

diesel_cars = 0.3*cars
print(diesel_cars)
# Out:
# 22.5
# 4.5

# %%
total_cars = cars + trucks
total_cars
# Out:
# 60

# %%
total_diesel_cars = diesel_cars + diesel_trucks
total_diesel_cars
# Out:
# 27.0

# %%
diesel_car_probability = total_diesel_cars / total_cars
diesel_car_probability
# Out:
# 0.45

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > **Warning  all values below is percents**!

# %%
first_tv_defects = 6/100
second_tv_defects = 5/100
third_tv_defects = 4/100

# %% [markdown]
# the shop got:

# %%
tvs_from_first = 20/100
tvs_from_second = 45/100
tvs_from_third = 1 - (20/100 +  45/100)

tvs_from_third
# Out:
# 0.35

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
defect_tvs_from_first = tvs_from_first * first_tv_defects
print(defect_tvs_from_first)

defect_tvs_from_second = tvs_from_second * second_tv_defects
print(defect_tvs_from_second)

defect_tvs_from_third = tvs_from_third * third_tv_defects
defect_tvs_from_third
# Out:
# 0.012
# 0.022500000000000003
# 0.013999999999999999

# %%
all_defect_tvs = defect_tvs_from_first + defect_tvs_from_second + defect_tvs_from_third
all_defect_tvs
# Out:
# 0.0485

# %%
all_good_tvs = 1 - all_defect_tvs
all_good_tvs
# Out:
# 0.9515

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
good_from_first = tvs_from_first * (1 - first_tv_defects)
good_from_first
# Out:
# 0.188

# %%
p_good_from_first_factory = good_from_first / all_good_tvs
p_good_from_first_factory
# Out:
# 0.19758276405675249
